# %% [markdown]
# ## Matrix and Vocabulary Construction - Code reuse

# %%
import pandas as pd

import numpy as np

from scipy import sparse

import nltk
from nltk import bigrams
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

# %%
news = pd.read_csv("./estadao_noticias_eleicao.csv", encoding="utf-8")

# %%
content = news.titulo + " " + news.subTitulo + " " + news.conteudo
content = content.fillna("")

# %%
def co_occurrence_matrix(corpus):
    vocab = set(corpus)
    vocab = list(vocab)
    n = len(vocab)
   
    vocab_to_index = {word:i for i, word in enumerate(vocab)}
    
    bi_grams = list(bigrams(corpus))

    bigram_freq = nltk.FreqDist(bi_grams).most_common(len(bi_grams))

    I=list()
    J=list()
    V=list()
    
    for bigram in bigram_freq:
        current = bigram[0][1]
        previous = bigram[0][0]
        count = bigram[1]

        I.append(vocab_to_index[previous])
        J.append(vocab_to_index[current])
        V.append(count)
        
    co_occurrence_matrix = sparse.coo_matrix((V,(I,J)), shape=(n,n))

    return co_occurrence_matrix, vocab_to_index

# %%
#Remove punctuation
tokenizer = RegexpTokenizer(r'\w+')
tokens_lists = content.apply(lambda text: tokenizer.tokenize(text.lower()))

# %%
#Remove stopwords
stopword_ = stopwords.words('portuguese')
#filtered_tokens = tokens_lists.apply(lambda tokens: [token for token in tokens if token not in stopword_])

#Transforming list of lists into one list
#tokens = [token for tokens_list in filtered_tokens for token in tokens_list]
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /opt/anaconda/anaconda3/lib/python3.6/site-packages/nltk/corpus/util.py in __load(self)
#      79             except LookupError as e:
# ---> 80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      81                 except LookupError: raise e
#
# /opt/anaconda/anaconda3/lib/python3.6/site-packages/nltk/data.py in find(resource_name, paths)
#     652     resource_not_found = '\n%s\n%s\n%s' % (sep, msg, sep)
# --> 653     raise LookupError(resource_not_found)
#     654
#
# LookupError:
# **********************************************************************
#   Resource 'corpora/stopwords.zip/stopwords/' not found.  Please
#   use the NLTK Downloader to obtain the resource:  >>>
#   nltk.download()
#   Searched in:
#     - '/home/arthurrso/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-230-8b0f78e52e48> in <module>()
#       1 #Remove stopwords
# ----> 2 stopword_ = stopwords.words('portuguese')
#       3 #filtered_tokens = tokens_lists.apply(lambda tokens: [token for token in tokens if token not in stopword_])
#       4
#       5 #Transforming list of lists into one list
#
# /opt/anaconda/anaconda3/lib/python3.6/site-packages/nltk/corpus/util.py in __getattr__(self, attr)
#     114             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     115
# --> 116         self.__load()
#     117         # This looks circular, but its not, since __load() changes our
#     118         # __class__ to something new:
#
# /opt/anaconda/anaconda3/lib/python3.6/site-packages/nltk/corpus/util.py in __load(self)
#      79             except LookupError as e:
#      80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
# ---> 81                 except LookupError: raise e
#      82
#      83         # Load the corpus.
#
# /opt/anaconda/anaconda3/lib/python3.6/site-packages/nltk/corpus/util.py in __load(self)
#      76         else:
#      77             try:
# ---> 78                 root = nltk.data.find('{}/{}'.format(self.subdir, self.__name))
#      79             except LookupError as e:
#      80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#
# /opt/anaconda/anaconda3/lib/python3.6/site-packages/nltk/data.py in find(resource_name, paths)
#     651     sep = '*' * 70
#     652     resource_not_found = '\n%s\n%s\n%s' % (sep, msg, sep)
# --> 653     raise LookupError(resource_not_found)
#     654
#     655
#
# LookupError:
# **********************************************************************
#   Resource 'corpora/stopwords' not found.  Please use the NLTK
#   Downloader to obtain the resource:  >>> nltk.download()
#   Searched in:
#     - '/home/arthurrso/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %%
matrix, vocab = co_occurrence_matrix(tokens)

# %% [markdown]
# ## Consult Bigram Frequency - Code reuse

# %%
consultable_matrix = matrix.tocsr()

# %%
def consult_frequency(w1, w2):
    return(consultable_matrix[vocab[w1],vocab[w2]])

# %% [markdown]
# ### Example - Code reuse

# %%
w1 = 'poucos'
w2 = 'recursos'
consult_frequency(w1, w2)
# Out:
# 3

# %% [markdown]
# ### 2.Escreva uma função que receba um certo termo de consulta e a matriz construída no passo 1 acima e retorne as top-3 palavras em ordem decrescente de frequencia.

# %%
def buildSortedList(expression):
    d = {}
    mostRecorrentWords = []
    #INDICES E DADOS POSSUEM NECESSARIAMENTE O MESMO TAMANHO.
    #DADOS É A QUANTIDADE DE VEZES QUE A PALAVRA ESTA ASSOCIADA
    indices = consultable_matrix[vocab[expression]].indices
    dados = consultable_matrix[vocab[expression]].data
    #VARRER O DICIONARIO DE PALAVRAS, BUSCAR A PALAVRA PELO INDICE E ASSOCIAR A ELA 
    #A QUANTIDADE DE VEZES QUE APARECE EM UM NOVO DICIONARIO
    for x in range(0, len(indices)-1):
        d[list(vocab.keys())[list(vocab.values()).index(x)]] = dados[x];
    
    sorted_d = sorted(d.items(), key=operator.itemgetter(1))
    mostRecorrentWords.append(sorted_d[-1])
    mostRecorrentWords.append(sorted_d[-2])
    mostRecorrentWords.append(sorted_d[-3])
    return mostRecorrentWords

# %%
expression = 'dilma'
print (buildSortedList(expression))
#print (consultable_matrix[vocab[expression]].indices)
#print (list(vocab.keys())[list(vocab.values()).index[1]])
#print(list(vocab.keys())[list(vocab.values())[0]])
# for name, age in list.items():  (for Python 3.x)
# Out:
# [('oferecem', 1966), ('foi,', 582), ('“oportunista”.', 533)]

# %%
print (list(vocab.keys()))
# Out:
# ['“reconheço', 'interiores', '750', 'história”,', 'colégios', 'dependa', 'analisá-la,', 'respeito!', 'davidson,', 'maranhão",', 'prejudicada,', 'resumindo', 'orgulha', '“alerta”.', 'avião;', 'regularizado.', 'feminino', 'ministro', 'patologia', '(pros-sp),', 'sexos', 'dívida”,', 'lidaria', 'benko,', 'exige-se', 'começar.', '1992)', 'valdomiro', 'berlusconi,', 'propagandear', 'cavallari', 'declarações:', 'pessoalmente,', '“odiado”,', 'geral;', 'instituímos', 'ensaiarem', 'ilustrada', 'ofensas,', 'm³/segundo', 'incomodar.', '(9.º).', 'mencionar', 'vendê-la.', 'modernizada', 'ira', 'dormiu', 'repete,', 'pernambuco?,', 'wagner,', '14/1996)', 'quadrados,', 'aparecido.', 'ressalvava', 'emitiremos', 'us$', 'aprovadas,', 'carisma”.', '89.', 'simonis,', 'exonerações', 'inclusive,', 'convida', 'manga', 'baixas', 'estatutária', 'pronatec,', 'lançado,', 'demover', 'tecnocrática', 'estimou', 'cenas', 'eunício:', 'processam-se', 'pedaço', 'multiplicar-se.', 'vazado', '19,7', 'prevaricou,', 'detendo', 'esperneia,', 'apela.', 'favoreçam', 'analisar”.', 'idade?', 'político-eleitoral,', '“administrados”', 'brasileiro"', 'niccolini', 'responsabilizado.', 'verde”', '(psb-sp)', 'analfabeto,', 'consenza', '“entregar”,', '53,01', 'candidatos?', 'aceitando', 'iphone', 'candidaturas…', 'tiros', 'postos.', 'abundantes', 'senado;', 'preparada,', 'enfermeiras', 'esforçam-se', 'waldez,', 'marinho”.', 'abrem', 'verve,', 'energético),', 'impedida', '302,2', 'faca', 'macacos”', 'browser', 'telmário', 'verifico', 'europeias.', 'surgir,', 'produzidos.', 'alimento', 'modalidades.', "'times'", 'nacional,', '9,6', 'percebendo,', 'fecha', 'torturadas', 'competitivo?', 'introspecção', 'a4', 'opressor', 'hélder', '“omissão', 'andaram', 'curto', '(equivalentes', 'católica?', '47,39%', 'tomate,', 'risco.', 'barreira”,', 'adesão,', '(escândalo', '“filhinho', 'chaveiros', 'vermelhas', 'criminalizador', '6.114', 'ocorreu;', 'assolou', 'blindaram', 'neopentecostal', 'dosimetria.', '(equivalente', 'flávia.', 'orelha,', 'gay”', 'barranco', 'uerj', 'espantosa”,', '(combinação', 'vilhena”.', 'continuava', 'aplaudida', '“burocracia', 'existir”.', 'palmada,', 'anuais', 'requerente', 'iluminada.', 'intervenção,', 'relacionada,', 'flw', 'endereços', 'arselino,', '5.700', 'mercadoria,', 'universidade.', 'sociais-democratas', 'crocco,', 'falas,', 'promoverem.', 'mensalão,', 'esforço,', 'entendeu-se', 'chile),', 'técnico”', 'classes,', 'carnelós', 'francesa”,', 'argélia', 'araguaia,', 'efeito.', 'pagot', '(desde', 'país.', 'viajaram,', 'registraria', 'didáticas', 'ceticismo', '(pt-rj).', 'denúncia;', 'clamor”.', '(12),', 'majoritário', 'tampão,', 'bitributação.', 'orçamentário.', 'custeou', 'pannunzio,', 'endividada.', 'borges)', 'milani.', 'desaprovado', 'tempo”,', 'destacarem', 'relação”,', 'enéas', 'vinculação', 'absolvam”.', '115%.', 'currículos,', 'esvaziamento.', '‘clivagem', '21h10.', '(rio', 'aparvalhados.', '“intelectual”', 'n.º', 'escravocrata,', 'explorações', 'comandante.', 'somadas,', 'fiscal’’,', 'moreno:', 'liquidificador,', 'submeter,', 'dificilmente', 'ptb.', 'consistir', 'linha-dura.', 'questionei', 'investigando”,', 'inocente”.', 'abrangência', 'autos.', 'efêmera', 'sigilos,', 'civil:', '6.449', 'tornem', 'urbanas,', 'posta”.', 'prostituição', 'marcam', 'desesperado', 'honesto', 'mencionam,', 'grave”,', 'desapropriou', 'fogão', '“roubado”', '2.0.', '"poderosos"', 'ultrapassagem', '8,59%', 'cpis,', 'individuais', 'verdadeira.', 'anômala', 'eleições.”', 'chancelado,', 'iniciante', '“tempos', '(grandes', 'nordestinos', 'vigorou', 'concorrências,', 'primo”,', 'penetração.', 'molejo', 'fosso', 'custeadas', 'formação,', 'otimizado.', '“sistema', 'ficção-científica.', 'existirá', 'perigoso,', 'banco?', 'enfiado', 'completa:', 'alterações,', 'guaratinguetá', 'inspirou', 'vieram.', '(abia)', 'depende,', 'trabalharmos', '“guardar”', 'derivadas', 'ponta,', 'entendemos', 'humana.', 'foi.”', 'etnias', '“aderido', 'monetária.', 'inexperientes,', 'infringiu', 'juruá.', 'menor.', ...

# %%
a = []
for x in vocab.keys():
    a.append(x)
for name, age in a.items():   
    if age == search_age:
        print (name)
